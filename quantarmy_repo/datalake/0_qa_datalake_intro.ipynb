# %%
from arcticdb import Arctic
import pandas as pd
from dotenv import load_dotenv
from os import getenv

# %%
dotenv_path = '/root/.env'
load_dotenv(dotenv_path)

endpoint = getenv("ENDPOINT")
db = getenv("DB")
access_key = getenv("ACCESS_KEY")
secret_key = getenv("SECRET_KEY")

# %%
ac = Arctic(f's3s://{endpoint}:{db}?access={access_key}&secret={secret_key}')

# %%
pd.DataFrame(ac.list_libraries())
# Out:
#                                  0
# 0                    ES.FUT.stable
# 1                    HE.FUT.stable
# 2                    HG.FUT.stable
# 3                    HO.FUT.stable
# 4                    KE.FUT.stable
# 5                    LE.FUT.stable
# 6                    NQ.FUT.stable
# 7                    PA.FUT.stable
# 8                    PL.FUT.stable
# 9                    RB.FUT.stable
# 10                   RX.FUT.stable
# 11                   SI.FUT.stable
# 12                  SR3.FUT.stable
# 13                   TN.FUT.stable
# 14                   YM.FUT.stable
# 15                   ZB.FUT.stable
# 16                   ZC.FUT.stable
# 17                   ZF.FUT.stable
# 18                   ZL.FUT.stable
# 19                   ZM.FUT.stable
# 20                   ZN.FUT.stable
# 21                   ZQ.FUT.stable
# 22                   ZS.FUT.stable
# 23                   ZT.FUT.stable
# 24                   ZW.FUT.stable
# 25             divs.etfs.us.stable
# 26           divs.stocks.us.stable
# 27        economic.calendar.stable
# 28    fundamental.stocks.us.stable
# 29                   gbonds.stable
# 30            idxcomponents.stable
# 31                idxprices.stable
# 32    index.historical.composition
# 33                    macro.stable
# 34                     meta.stable
# 35                   mktcap.stable
# 36           prices.cryptos.stable
# 37           prices.etfs.us.stable
# 38             prices.money.stable
# 39         prices.stocks.us.stable
# 40            prices.yields.stable
# 41                sentiment.stable
# 42           splits.etfs.us.stable
# 43         splits.stocks.us.stable
# 44        stocks.holders.us.stable
# 45      stocks.insidiers.us.stable
# 46   us.stocks.fundamental.balance
# 47  us.stocks.fundamental.cashflow
# 48    us.stocks.fundamental.income
# 49           us.stocks.news.stable
